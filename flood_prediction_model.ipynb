# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
from pickle import dump, load
sb.set() # set the default Seaborn style for graphics

# %%
fcd = pd.read_csv('resources/FannoCreekDurham.1.csv')
fcd.head()
# Out:
# C:\Users\Nemy\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            # Unnamed: 1      Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  agency_cd    site_no        datetime   timezone  Gage Height [ft]
# 1       USGS   14206950  11/1/2015 0:00        PDT              6.34
# 2       USGS   14206950  11/1/2015 0:15        PDT              6.36
# 3       USGS   14206950  11/1/2015 0:30        PDT              6.32
# 4       USGS   14206950  11/1/2015 0:45        PDT              6.31
#
#         Unnamed: 5               Unnamed: 6       Unnamed: 7 Unnamed: 8
# 0  Discharge [cfs]  Temperature [degrees C]  Turbidity [FNU]   Flooding
# 1              511                     14.4             77.1          0
# 2              514                      NaN              NaN          0
# 3              508                      NaN              NaN          0
# 4              506                      NaN              NaN          0

# %%
fcd_1=pd.DataFrame.dropna(fcd)

# %%
fcd_2 = fcd_1.iloc[1:]
fcd_2.head()
# Out:
#        # Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1   USGS   14206950  11/1/2015 0:00        PDT       6.34        511
# 5   USGS   14206950  11/1/2015 1:00        PDT       6.33        509
# 6   USGS   14206950  11/1/2015 1:00        PST       6.36        514
# 13  USGS   14206950  11/1/2015 2:00        PST       6.39        519
# 17  USGS   14206950  11/1/2015 3:00        PST       6.43        526
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 1        14.4       77.1          0
# 5        14.4       72.6          0
# 6        14.3         61          0
# 13       14.2       54.4          0
# 17       14.2         44          0

# %%
fcd_2.columns=['Agency_cd','Site_No','Datetime','Timezone','Gage Height','Discharge','Temperature','Turbidity','Flooding']
fcd_2.head()
# Out:
#    Agency_cd   Site_No        Datetime Timezone Gage Height Discharge  \
# 1       USGS  14206950  11/1/2015 0:00      PDT        6.34       511
# 5       USGS  14206950  11/1/2015 1:00      PDT        6.33       509
# 6       USGS  14206950  11/1/2015 1:00      PST        6.36       514
# 13      USGS  14206950  11/1/2015 2:00      PST        6.39       519
# 17      USGS  14206950  11/1/2015 3:00      PST        6.43       526
#
#    Temperature Turbidity Flooding
# 1         14.4      77.1        0
# 5         14.4      72.6        0
# 6         14.3        61        0
# 13        14.2      54.4        0
# 17        14.2        44        0

# %%
fc5 = pd.read_csv('resources/FannoCreek56th.csv')
fc5.head()
# Out:
# C:\Users\Nemy\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   # ---------------------------------- WARNING ----------------------------------------  \
# 0  # Some of the data that you have obtained from...
# 1  # may not have received Director's approval. A...
# 2  # as provisional and are subject to revision. ...
# 3  # condition that neither the USGS nor the Unit...
# 4          # for any damages resulting from its use.
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %%
fc5_1=pd.DataFrame.dropna(fc5)

# %%
fc5_2 = fc5_1.iloc[1:]
fc5_2.head()
# Out:
#    # ---------------------------------- WARNING ----------------------------------------  \
# 25                                               USGS
# 26                                               USGS
# 27                                               USGS
# 28                                               USGS
# 29                                               USGS
#
#    Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 25   14206900  11/1/2015 0:00        PDT       9.03       8.86
# 26   14206900  11/1/2015 0:15        PDT       9.03       8.86
# 27   14206900  11/1/2015 0:30        PDT          9        7.9
# 28   14206900  11/1/2015 0:45        PDT          9        7.9
# 29   14206900  11/1/2015 1:00        PDT       8.97       7.01

# %%
fc5_2.columns=['Agency_cd','Site_No','Datetime','Timezone','Gage Height','Discharge']
fc5_2.head()
# Out:
#    Agency_cd   Site_No        Datetime Timezone Gage Height Discharge
# 25      USGS  14206900  11/1/2015 0:00      PDT        9.03      8.86
# 26      USGS  14206900  11/1/2015 0:15      PDT        9.03      8.86
# 27      USGS  14206900  11/1/2015 0:30      PDT           9       7.9
# 28      USGS  14206900  11/1/2015 0:45      PDT           9       7.9
# 29      USGS  14206900  11/1/2015 1:00      PDT        8.97      7.01

# %%
fcd_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26528 entries, 1 to 72593
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Agency_cd    26528 non-null  object
#  1   Site_No      26528 non-null  object
#  2   Datetime     26528 non-null  object
#  3   Timezone     26528 non-null  object
#  4   Gage Height  26528 non-null  object
#  5   Discharge    26528 non-null  object
#  6   Temperature  26528 non-null  object
#  7   Turbidity    26528 non-null  object
#  8   Flooding     26528 non-null  object
# dtypes: object(9)
# memory usage: 2.0+ MB

# %%
fc5_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78689 entries, 25 to 78713
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Agency_cd    78689 non-null  object
#  1   Site_No      78689 non-null  object
#  2   Datetime     78689 non-null  object
#  3   Timezone     78689 non-null  object
#  4   Gage Height  78689 non-null  object
#  5   Discharge    78689 non-null  object
# dtypes: object(6)
# memory usage: 4.2+ MB

# %%
fcd_3= pd.DataFrame(fcd_2[['Gage Height','Discharge','Temperature','Turbidity','Flooding']])

# %%
fcd_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26528 entries, 1 to 72593
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gage Height  26528 non-null  object
#  1   Discharge    26528 non-null  object
#  2   Temperature  26528 non-null  object
#  3   Turbidity    26528 non-null  object
#  4   Flooding     26528 non-null  object
# dtypes: object(5)
# memory usage: 1.2+ MB

# %%
fcd_4=fcd_3.apply(pd.to_numeric,errors='coerce')
fcd_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26528 entries, 1 to 72593
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gage Height  26528 non-null  float64
#  1   Discharge    26528 non-null  float64
#  2   Temperature  26528 non-null  float64
#  3   Turbidity    26528 non-null  float64
#  4   Flooding     26528 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 1.2 MB

# %%
fc5_3= pd.DataFrame(fc5_2[['Gage Height','Discharge']])

# %%
fc5_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78689 entries, 25 to 78713
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gage Height  78689 non-null  object
#  1   Discharge    78689 non-null  object
# dtypes: object(2)
# memory usage: 1.8+ MB

# %%
fc5_4=fc5_3.apply(pd.to_numeric,errors='coerce')
fc5_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78689 entries, 25 to 78713
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gage Height  78689 non-null  float64
#  1   Discharge    78689 non-null  float64
# dtypes: float64(2)
# memory usage: 1.8 MB

# %%
frames = [fcd_4,fc5_4]
combined = pd.concat(frames,axis=0)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105217 entries, 1 to 78713
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Gage Height  105217 non-null  float64
#  1   Discharge    105217 non-null  float64
#  2   Temperature  26528 non-null   float64
#  3   Turbidity    26528 non-null   float64
#  4   Flooding     26528 non-null   float64
# dtypes: float64(5)
# memory usage: 4.8 MB

# %%
combined.head()
# Out:
#     Gage Height  Discharge  Temperature  Turbidity  Flooding
# 1          6.34      511.0         14.4       77.1       0.0
# 5          6.33      509.0         14.4       72.6       0.0
# 6          6.36      514.0         14.3       61.0       0.0
# 13         6.39      519.0         14.2       54.4       0.0
# 17         6.43      526.0         14.2       44.0       0.0

# %%
pd.plotting.scatter_matrix(combined,figsize=(12,24))
# Out:
# array([[<AxesSubplot:xlabel='Gage Height', ylabel='Gage Height'>,
#         <AxesSubplot:xlabel='Discharge', ylabel='Gage Height'>,
#         <AxesSubplot:xlabel='Temperature', ylabel='Gage Height'>,
#         <AxesSubplot:xlabel='Turbidity', ylabel='Gage Height'>,
#         <AxesSubplot:xlabel='Flooding', ylabel='Gage Height'>],
#        [<AxesSubplot:xlabel='Gage Height', ylabel='Discharge'>,
#         <AxesSubplot:xlabel='Discharge', ylabel='Discharge'>,
#         <AxesSubplot:xlabel='Temperature', ylabel='Discharge'>,
#         <AxesSubplot:xlabel='Turbidity', ylabel='Discharge'>,
#         <AxesSubplot:xlabel='Flooding', ylabel='Discharge'>],
#        [<AxesSubplot:xlabel='Gage Height', ylabel='Temperature'>,
#         <AxesSubplot:xlabel='Discharge', ylabel='Temperature'>,
#         <AxesSubplot:xlabel='Temperature', ylabel='Temperature'>,
#         <AxesSubplot:xlabel='Turbidity', ylabel='Temperature'>,
#         <AxesSubplot:xlabel='Flooding', ylabel='Temperature'>],
#        [<AxesSubplot:xlabel='Gage Height', ylabel='Turbidity'>,
#         <AxesSubplot:xlabel='Discharge', ylabel='Turbidity'>,
#         <AxesSubplot:xlabel='Temperature', ylabel='Turbidity'>,
#         <AxesSubplot:xlabel='Turbidity', ylabel='Turbidity'>,
#         <AxesSubplot:xlabel='Flooding', ylabel='Turbidity'>],
#        [<AxesSubplot:xlabel='Gage Height', ylabel='Flooding'>,
#         <AxesSubplot:xlabel='Discharge', ylabel='Flooding'>,
#         <AxesSubplot:xlabel='Temperature', ylabel='Flooding'>,
#         <AxesSubplot:xlabel='Turbidity', ylabel='Flooding'>,
#         <AxesSubplot:xlabel='Flooding', ylabel='Flooding'>]], dtype=object)

# %%
combined.corr()
# Out:
#              Gage Height  Discharge  Temperature  Turbidity  Flooding
# Gage Height     1.000000  -0.161261    -0.504732   0.784336  0.181711
# Discharge      -0.161261   1.000000    -0.350444   0.698978  0.198738
# Temperature    -0.504732  -0.350444     1.000000  -0.422091 -0.139261
# Turbidity       0.784336   0.698978    -0.422091   1.000000  0.149592
# Flooding        0.181711   0.198738    -0.139261   0.149592  1.000000

# %%
sb.heatmap(combined.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
combined_1=pd.DataFrame.dropna(combined)
combined_1.head(n=70000)
# Out:
#        Gage Height  Discharge  Temperature  Turbidity  Flooding
# 1             6.34      511.0         14.4       77.1       0.0
# 5             6.33      509.0         14.4       72.6       0.0
# 6             6.36      514.0         14.3       61.0       0.0
# 13            6.39      519.0         14.2       54.4       0.0
# 17            6.43      526.0         14.2       44.0       0.0
# ...            ...        ...          ...        ...       ...
# 72585         2.79       57.7          8.6       10.8       0.0
# 72587         2.78       57.0          8.6       10.1       0.0
# 72589         2.77       56.2          8.6       10.2       0.0
# 72591         2.76       55.5          8.6       10.0       0.0
# 72593         2.74       54.0          8.5        9.8       0.0
#
# [26528 rows x 5 columns]

# %%
predictors = ['Gage Height','Discharge','Turbidity']
y = pd.DataFrame(combined_1["Flooding"])
X = pd.DataFrame(combined_1[predictors])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (19896, 1) (19896, 3)
# Test Set  : (6632, 1) (6632, 3)

# %%
rforest = RandomForestClassifier(n_estimators = 100, max_depth = 4)  # create the object
rforest.fit(X_train, y_train.values.ravel())                         # train the model

# Predict Response corresponding to Predictors
y_train_pred = rforest.predict(X_train)
y_test_pred = rforest.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", rforest.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", rforest.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9880377965420185
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9874849215922799
# <AxesSubplot:>
